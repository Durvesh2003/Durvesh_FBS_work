# %%
print('first line')
# Out:
# first line

# %% [markdown]
# # heading
# ## heading
# ### heading
# ### heading
# #### heading
# ##### heading
# ###### heading

# %% [markdown]
# ### Basics shortcuts for notebook
# 1. a is used to add cell above
# 2. b is used to add cell below
# 3. dd delete cell
# 4. m maekdown
# 5. y code
# 6. shift + enter : execute current cell and add new cell
# 7. ctrl + enter : execute current cell
